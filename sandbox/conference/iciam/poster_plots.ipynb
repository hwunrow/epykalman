# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import gamma

# Parameters for the gamma distribution
scale = 1.0  # Scale parameter

for i, shape in enumerate([5.0, 8.0, 11.0, 14.0, 17.0, 20.]):
    # Create a gamma distribution object
    gamma_dist = gamma(a=shape*1.01**i, scale=scale)

    # Generate x values
    x = np.linspace(1*i, 20 + 2.4*i, 500)

    # Calculate the gamma distribution values
    y = gamma_dist.pdf(x)
    fig, ax = plt.subplots(figsize=(6, 4))
    ax.fill_between(x, y, color='lightgreen', alpha=1)
    ax.plot(x, y, color='black', linewidth=5)
    ax.axis('off')  # Turn off axes
    
    plt.savefig(f'filter_dist_{i}.svg', format='svg', bbox_inches='tight', transparent=True)

# %%
from scipy.stats import uniform

unif_dist = uniform(0, 12)

# Generate x values
x = np.linspace(0, 1, 500)

# Calculate the gamma distribution values
y = unif_dist.pdf(x)
fig, ax = plt.subplots(figsize=(6, 4))
ax.fill_between(x, y, color='lightgrey', alpha=0.5)
ax.plot(x, y, color='black', linewidth=5)
ax.axis('off')  # Turn off axes

plt.savefig(f'unif_dist.svg', format='svg', bbox_inches='tight', transparent=True)

# %%
# Parameters for the gamma distribution
scale = 0.75  # Scale parameter

for i, shape in enumerate([5.0, 8.0, 11.0, 14.0, 17.0, 20.]):
    # Create a gamma distribution object
    gamma_dist = gamma(a=shape*1.01**i, scale=scale)

    # Generate x values
    x = np.linspace(1*i, 15 + 2.4*i, 500)

    # Calculate the gamma distribution values
    y = gamma_dist.pdf(x)
    fig, ax = plt.subplots(figsize=(6, 4))
    ax.fill_between(x, y, color='orange', alpha=1)
    ax.plot(x, y, color='black', linewidth=5)
    ax.axis('off')  # Turn off axes
    plt.savefig(f'smooth_dist_{i}.svg', format='svg', bbox_inches='tight', transparent=True)

# %%
gamma_dist = gamma(a=20, scale=1)

# Generate x values
x = np.linspace(1, 50, 5000)

# Calculate the gamma distribution values
y = gamma_dist.pdf(x)
fig, ax = plt.subplots(figsize=(6, 4))
ax.fill_between(x, y, color='green', alpha=1)
ax.plot(x, y, color='black', linewidth=5)
ax.axis('off')  # Turn off axes
plt.savefig(f'smooth_dist.svg', format='svg', bbox_inches='tight', transparent=True)
