# %%
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
from tqdm import tqdm

# Define SIR model
def sir_model(t, y, beta, gamma):
    S, I, R = y
    N = S + I + R
    dSdt = -beta(t) * S * I / N
    dIdt = beta(t) * S * I / N - gamma * I
    dRdt = gamma * I
    return [dSdt, dIdt, dRdt]

# Define sigmoid function for beta
def beta_func(t, beta_0, beta_1, k, m):
    return beta_0 + (beta_1 - beta_0) / (1 + np.exp(-k * (t - m)))

# %%
true_params = {
    'rt_0': 1.4,
    'rt_1': 3.,
    'midpoint': 100.,
    'k': 0.1,
    'n_t': 365,
    't_I': 4.,
    'N': 100_000.,
    'S0': 99_900.,
    'I0': 100.,
}

y0 = [99_900, 100, 0]
tspan = [0, 365]
t_eval = np.arange(tspan[0], tspan[1])
gamma = 0.25
k = 0.1
m = 100
beta_0_range = np.linspace(0, 1, 100)
beta_1_range = np.linspace(0, 1, 100)

for beta_0 in tqdm(beta_0_range):
    for beta_1 in beta_1_range:
        sol = solve_ivp(lambda t, y: sir_model(t, y, lambda t: beta_func(t, beta_0, beta_1, k, m), gamma), tspan, y0, t_eval=t_eval)
# Out:
#  22%|███████████████████▏                                                                   | 22/100 [00:08<00:30,  2.58it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 24
#      22 for beta_0 in tqdm(beta_0_range):
#      23     for beta_1 in beta_1_range:
# ---> 24         sol = solve_ivp(lambda t, y: sir_model(t, y, lambda t: beta_func(t, beta_0, beta_1, k, m), gamma), tspan, y0, t_eval=t_eval)
#
# File /opt/anaconda3/envs/rt-estimation/lib/python3.10/site-packages/scipy/integrate/_ivp/ivp.py:589, in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     587 status = None
#     588 while status is None:
# --> 589     message = solver.step()
#     591     if solver.status == 'finished':
#     592         status = 0
#
# File /opt/anaconda3/envs/rt-estimation/lib/python3.10/site-packages/scipy/integrate/_ivp/base.py:181, in OdeSolver.step(self)
#     179 else:
#     180     t = self.t
# --> 181     success, message = self._step_impl()
#     183     if not success:
#     184         self.status = 'failed'
#
# File /opt/anaconda3/envs/rt-estimation/lib/python3.10/site-packages/scipy/integrate/_ivp/rk.py:147, in RungeKutta._step_impl(self)
#     144 y_new, f_new = rk_step(self.fun, t, y, self.f, h, self.A,
#     145                        self.B, self.C, self.K)
#     146 scale = atol + np.maximum(np.abs(y), np.abs(y_new)) * rtol
# --> 147 error_norm = self._estimate_error_norm(self.K, h, scale)
#     149 if error_norm < 1:
#     150     if error_norm == 0:
#
# File /opt/anaconda3/envs/rt-estimation/lib/python3.10/site-packages/scipy/integrate/_ivp/rk.py:109, in RungeKutta._estimate_error_norm(self, K, h, scale)
#     108 def _estimate_error_norm(self, K, h, scale):
# --> 109     return norm(self._estimate_error(K, h) / scale)
#
# File /opt/anaconda3/envs/rt-estimation/lib/python3.10/site-packages/scipy/integrate/_ivp/common.py:63, in norm(x)
#      61 def norm(x):
#      62     """Compute RMS norm."""
# ---> 63     return np.linalg.norm(x) / x.size ** 0.5
#
# File <__array_function__ internals>:180, in norm(*args, **kwargs)
#
# File /opt/anaconda3/envs/rt-estimation/lib/python3.10/site-packages/numpy/linalg/linalg.py:2527, in norm(x, ord, axis, keepdims)
#    2525 else:
#    2526     sqnorm = x.dot(x)
# -> 2527 ret = sqrt(sqnorm)
#    2528 if keepdims:
#    2529     ret = ret.reshape(ndim*[1])
#
# KeyboardInterrupt:

# %%
plt.plot(sol.y[1])
